# %%
import pandas as pd

df = pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
ax = df['grade'].plot.hist()

# %%
df['yr_renovated'] = list(zip(df['yr_renovated'], df['yr_built']))
df['yr_renovated'] = df['yr_renovated'].apply(lambda x: max(x[0], x[1]))
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df = df.drop(['lat', 'long'], axis=1)
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode  sqft_living15  sqft_lot15
# ...

# %%
df['since_renovation'] = list(zip(df['yr_renovated'], df['date']))
df['since_renovation'] = df['since_renovation'].apply(lambda x: int(x[1][:4]) - x[0])
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode  sqft_living15  sqft_lot15  \
# ...

# %%
df['age'] = list(zip(df['yr_built'], df['date']))
df['age'] = df['age'].apply(lambda x: int(x[1][:4]) - x[0])
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df['date'] = df['date'].apply(lambda x: x[:8])
df.head()
# Out:
#            id      date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520  20141013  221900.0         3       1.00         1180      5650
# 1  6414100192  20141209  538000.0         3       2.25         2570      7242
# 2  5631500400  20150225  180000.0         2       1.00          770     10000
# 3  2487200875  20141209  604000.0         4       3.00         1960      5000
# 4  1954400510  20150218  510000.0         3       2.00         1680      8080
#
#    floors  waterfront  view  ...  grade  sqft_above  sqft_basement  yr_built  \
# 0     1.0           0     0  ...      7        1180              0      1955
# 1     2.0           0     0  ...      7        2170            400      1951
# 2     1.0           0     0  ...      6         770              0      1933
# 3     1.0           0     0  ...      7        1050            910      1965
# 4     1.0           0     0  ...      8        1680              0      1987
#
# ...

# %%
df = df.drop(['yr_built', 'yr_renovated', 'zipcode'], axis=1)
df.head()
# Out:
#            id      date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  7129300520  20141013  221900.0         3       1.00         1180      5650
# 1  6414100192  20141209  538000.0         3       2.25         2570      7242
# 2  5631500400  20150225  180000.0         2       1.00          770     10000
# 3  2487200875  20141209  604000.0         4       3.00         1960      5000
# 4  1954400510  20150218  510000.0         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    sqft_living15  sqft_lot15  since_renovation  age
# ...

# %%
df = df.drop('id', axis=1)
df.head()
# Out:
#        date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  20141013  221900.0         3       1.00         1180      5650     1.0
# 1  20141209  538000.0         3       2.25         2570      7242     2.0
# 2  20150225  180000.0         2       1.00          770     10000     1.0
# 3  20141209  604000.0         4       3.00         1960      5000     1.0
# 4  20150218  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0           0     0          3      7        1180              0
# 1           0     0          3      7        2170            400
# 2           0     0          3      6         770              0
# 3           0     0          5      7        1050            910
# 4           0     0          3      8        1680              0
#
#    sqft_living15  sqft_lot15  since_renovation  age
# 0           1340        5650                59   59
# ...

# %%
ax = df['price'].plot.hist()

# %%
for i in range(100):
    df['price'] = df['price'].loc[df['price'] != df['price'].max()]
df['price'].plot.hist()

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront          0
# view                0
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# sqft_living15       0
# sqft_lot15          0
# since_renovation    0
# age                 0
# dtype: int64

# %%
prices = df['price']
prices
# Out:
# 0         221900.0
# 1         538000.0
# 2         180000.0
# 3         604000.0
# 4         510000.0
# 5        1225000.0
# 6         257500.0
# 7         291850.0
# 8         229500.0
# 9         323000.0
# 10        662500.0
# 11        468000.0
# 12        310000.0
# 13        400000.0
# 14        530000.0
# 15        650000.0
# 16        395000.0
# 17        485000.0
# 18        189000.0
# 19        230000.0
# 20        385000.0
# 21       2000000.0
# 22        285000.0
# 23        252700.0
# 24        329000.0
# 25        233000.0
# 26        937000.0
# 27        667000.0
# 28        438000.0
# 29        719000.0
#            ...
# 21583     399950.0
# 21584     380000.0
# 21585     270000.0
# 21586     505000.0
# 21587     385000.0
# 21588     414500.0
# 21589     347500.0
# 21590    1222500.0
# 21591     572000.0
# 21592     475000.0
# 21593    1088000.0
# 21594     350000.0
# 21595     520000.0
# 21596     679950.0
# 21597    1575000.0
# 21598     541800.0
# ...

# %%
df = df.drop(columns='price')

# %%
from sklearn import preprocessing
df = preprocessing.scale(df)
df = pd.DataFrame(df, columns=['date','bedrooms','bathrooms','sqft_living','sqft_lot','floors','waterfront','view','condition','grades','qft_above','sqft_basement','sqft_living15','sqft_lot15','since_renovation','age'])
df.head()
# Out:
#        date  bedrooms  bathrooms  sqft_living  sqft_lot    floors  waterfront  \
# 0 -0.651379 -0.392441  -1.467428    -1.008619 -0.226690 -0.911263   -0.075625
# 1 -0.607199 -0.392441   0.198385     0.590934 -0.188327  0.942631   -0.075625
# 2  1.425063 -1.472826  -1.467428    -1.480430 -0.121866 -0.911263   -0.075625
# 3 -0.607199  0.687943   1.197873    -0.111028 -0.242353 -0.911263   -0.075625
# 4  1.423485 -0.392441  -0.134778    -0.433240 -0.168133 -0.911263   -0.075625
#
#        view  condition    grades  qft_above  sqft_basement  sqft_living15  \
# 0 -0.298945  -0.628933 -0.553961  -0.741387      -0.661031      -0.945911
# 1 -0.298945  -0.628933 -0.553961   0.500661       0.264962      -0.424491
# 2 -0.298945  -0.628933 -1.428992  -1.255771      -0.661031       1.109973
# 3 -0.298945   2.447475 -0.553961  -0.904485       1.445603      -0.916116
# 4 -0.298945  -0.628933  0.321070  -0.114090      -0.661031      -0.260617
#
#    sqft_lot15  since_renovation       age
# ...

# %%
s = df.shape[0]
s
train1 = df.take(list(range(0, s//3)))
train2 = df.take(list(range(s//3, 2*s//3)))
train3 = df.take(list(range(2*s//3, s)))
prices1 = prices.take(list(range(0, s//3)))
prices2 = prices.take(list(range(s//3, 2*s//3)))
prices3 = prices.take(list(range(2*s//3, s)))

# %%
from sklearn import linear_model
reg = linear_model.LinearRegression()
reg.fit(train1, prices1)
reg.coef_
# Out:
# array([  9980.07262244, -17477.77727481,  28496.02509426,  36928.37229138,
#          8912.94848123,  23009.1546475 ,  27942.26648384,  27397.60732901,
#         15272.61611228, 127485.53023553,  28979.86678766,  20815.15257952,
#         47594.11036912,  -9797.33143111,   -568.49402209, 103117.74097211])

# %%
rid = linear_model.Ridge()
rid.fit(train2, prices2)
rid.coef_
# Out:
# array([  9880.81371016, -22124.61693126,  24894.49622692,  46756.54134341,
#          2266.8366689 ,  21693.18816363,  16223.20021435,  25165.00520749,
#         13784.19146062, 127010.88000141,  35290.69438734,  28941.74557501,
#         42498.01130761, -10880.30636316, -22354.01186808, 121592.56474946])

# %%
las = linear_model.Lasso()
las.fit(train3, prices3)
las.coef_
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7325530730492.406, tolerance: 66710833868.957504
#   positive)
# array([   9232.61382945,  -22192.57229398,   28101.01492593,
#         208707.88053418,    -370.1287615 ,   25672.26697068,
#          17656.59065277,   33970.55402783,   14459.73278752,
#         137896.17590265, -103827.17541781,  -43772.77224393,
#          15129.07932119,   -9080.79038938,   -3557.23630567,
#          91897.62986388])

# %%
import matplotlib.pyplot as plt
regl = [reg.score(train2, prices2), reg.score(train3, prices3)]
ridl = [rid.score(train1, prices1), rid.score(train3, prices3)]
lasl = [las.score(train1, prices1), las.score(train2, prices2)]
plt.plot([2, 3], regl, "ro", label='Regular')
plt.plot([1, 3], ridl, "bo", label='Ridge')
plt.plot([1, 2], lasl, "go", label='Lasso')
plt.legend(loc='upper right')
plt.title('Score')
plt.show()
